# %% [markdown]
# EDA movies dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# cargamos el dataset
movies_df = pd.read_csv("movies_dataset_processed.csv")

# %%
# visualizamos cuantas filas y columnas tiene el dataset asi como los nombres y tipos de datos de columnas
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45451 entries, 0 to 45450
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   budget                      45451 non-null  float64
#  1   id                          45451 non-null  int64
#  2   original_language           45440 non-null  object
#  3   overview                    44510 non-null  object
#  4   popularity                  45451 non-null  float64
#  5   release_date                45451 non-null  object
#  6   revenue                     45451 non-null  float64
#  7   runtime                     45205 non-null  float64
#  8   spoken_languages            45451 non-null  object
#  9   status                      45371 non-null  object
#  10  tagline                     20425 non-null  object
#  11  title                       45451 non-null  object
#  12  vote_average                45451 non-null  float64
#  13  vote_count                  45451 non-null  float64
#  14  cast                        45451 non-null  object
#  15  crew                        45451 non-null  object
#  16  director                    44616 non-null  object
#  17  belongs_to_collection_name  4497 non-null   object
#  18  production_companies_name   45451 non-null  object
#  19  spoken_languages_name       45451 non-null  object
#  20  production_countries_name   45451 non-null  object
#  21  year                        45451 non-null  int64
#  22  return_of_investment        45451 non-null  float64
# dtypes: float64(7), int64(2), object(14)
# memory usage: 8.0+ MB

# %%
#previsualizamos el contendio de las 5 primeras filas
movies_df.head(5)
# Out:
#        budget     id original_language  \
# 0  30000000.0    862                en
# 1  65000000.0   8844                en
# 2         0.0  15602                en
# 3  16000000.0  31357                en
# 4         0.0  11862                en
#
#                                             overview  popularity release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943   1995-10-30
# 1  When siblings Judy and Peter discover an encha...   17.015539   1995-12-15
# 2  A family wedding reignites the ancient feud be...   11.712900   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...    3.859495   1995-12-22
# 4  Just when George Banks has recovered from his ...    8.387519   1995-02-10
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554050.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797250.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0    101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452160.0    127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578910.0    106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status  ... vote_count  \
# 0  Released  ...     5415.0
# 1  Released  ...     2413.0
# 2  Released  ...       92.0
# 3  Released  ...       34.0
# 4  Released  ...      173.0
#
#                                                 cast  \
# 0  ['Tom Hanks', 'Tim Allen', 'Don Rickles', 'Jim...
# 1  ['Robin Williams', 'Jonathan Hyde', 'Kirsten D...
# 2  ['Walter Matthau', 'Jack Lemmon', 'Ann-Margret...
# 3  ['Whitney Houston', 'Angela Bassett', 'Loretta...
# 4  ['Steve Martin', 'Diane Keaton', 'Martin Short...
#
#                                                 crew         director  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    John Lasseter
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...     Joe Johnston
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...    Howard Deutch
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  Forest Whitaker
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...    Charles Shyer
#
#        belongs_to_collection_name  \
# 0            Toy Story Collection
# 1                             NaN
# 2       Grumpy Old Men Collection
# 3                             NaN
# 4  Father of the Bride Collection
#
#                            production_companies_name    spoken_languages_name  \
# 0                        ['Pixar Animation Studios']              ['English']
# 1  ['TriStar Pictures', 'Teitler Film', 'Intersco...  ['English', 'Français']
# 2                 ['Warner Bros.', 'Lancaster Gate']              ['English']
# 3         ['Twentieth Century Fox Film Corporation']              ['English']
# 4   ['Sandollar Productions', 'Touchstone Pictures']              ['English']
#
#       production_countries_name  year return_of_investment
# 0  ['United States of America']  1995            12.451802
# 1  ['United States of America']  1995             4.043035
# 2  ['United States of America']  1995             0.000000
# 3  ['United States of America']  1995             5.090760
# 4  ['United States of America']  1995             0.000000
#
# [5 rows x 23 columns]

# %%
# Analizamos las columnas de tipo numero
describe_cols = ["budget", "popularity", "revenue", "runtime", "vote_average", "vote_count", "year", "return_of_investment"]
movies_df[describe_cols].describe()
# Out:
#              budget    popularity       revenue       runtime  vote_average  \
# count  4.545100e+04  45451.000000  4.545100e+04  45205.000000  45451.000000
# mean   4.231294e+06      2.926887  1.121930e+07     94.181905      5.624085
# std    1.742942e+07      6.006458  6.433984e+07     38.329504      1.915424
# min    0.000000e+00      0.000000  0.000000e+00      0.000000      0.000000
# 25%    0.000000e+00      0.389095  0.000000e+00     85.000000      5.000000
# 50%    0.000000e+00      1.131386  0.000000e+00     95.000000      6.000000
# 75%    0.000000e+00      3.694370  0.000000e+00    107.000000      6.800000
# max    3.800000e+08    547.488298  2.787965e+09   1256.000000     10.000000
#
#          vote_count          year  return_of_investment
# count  45451.000000  45451.000000          4.545100e+04
# mean     109.989703   1991.882027          6.589542e+02
# std      491.352336     24.057726          7.463165e+04
# min        0.000000   1874.000000          0.000000e+00
# 25%        3.000000   1978.000000          0.000000e+00
# 50%       10.000000   2001.000000          0.000000e+00
# 75%       34.000000   2010.000000          0.000000e+00
# max    14075.000000   2020.000000          1.239638e+07

# %%
# TOP 10 mas populares
populares= movies_df.sort_values('popularity', ascending=False)

plt.figure(figsize=(12,4))

plt.barh(populares['title'].head(10),populares['popularity'].head(10), align='center',
        color='green')
plt.gca().invert_yaxis()
plt.xlabel("Popularidad")
plt.title("TOP 10 peliculas mas populares")
# Out:
# Text(0.5, 1.0, 'TOP 10 peliculas mas populares')

# %%
# Calcula la matriz de correlación
matriz_correlacion = movies_df[describe_cols].corr()

# Crea el mapa de calor del gráfico de correlación
plt.figure(figsize=(10, 8))
sns.heatmap(matriz_correlacion, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Matriz de Correlación')
plt.show()

# %%
# peliculas que obtuvieron ganancias
print(movies_df[["budget", "revenue", "return_of_investment"]].head(5))
pelis_con_roi = movies_df[movies_df['return_of_investment'] > 0]
pelis_con_roi.shape
# Out:
#        budget      revenue  return_of_investment
# 0  30000000.0  373554050.0             12.451802
# 1  65000000.0  262797250.0              4.043035
# 2         0.0          0.0              0.000000
# 3  16000000.0   81452160.0              5.090760
# 4         0.0   76578910.0              0.000000
# (5393, 23)

# %% [markdown]
# Modelo de recomendaciones

# %%
#importar librerias para creacion de modelo
from sklearn.feature_extraction.text import TfidfVectorizer

#Define a TF-IDF Vectorizer Object. 
tfidf = TfidfVectorizer(stop_words='english')

# remplaza valores NAN con str vacio
movies_df['overview'] = movies_df['overview'].fillna('')
muestra = movies_df["overview"].head(10000)


# Construir la matriz TF-IDF necesaria ajustando y transformando los datos.
tfidf_matrix = tfidf.fit_transform(muestra)


tfidf_matrix.shape
# Out:
# (10000, 32280)

# %%
# Import linear_kernel
from sklearn.metrics.pairwise import linear_kernel

# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
#Construct a reverse map of indices and movie titles
indices = pd.Series(movies_df.index, index=movies_df['title']).drop_duplicates()

# %%
# Function that takes in movie title as input and outputs most similar movies
def get_recommendations(title, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:6]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return movies_df['title'].iloc[movie_indices]

# %%
get_recommendations('The Dark Knight Rises')
# Out:
# 12520                                      The Dark Knight
# 150                                         Batman Forever
# 1335                                        Batman Returns
# 15569                           Batman: Under the Red Hood
# 585                                                 Batman
# 21245    Batman Unmasked: The Psychology of the Dark Kn...
# 9259                    Batman Beyond: Return of the Joker
# 18096                                     Batman: Year One
# 19847              Batman: The Dark Knight Returns, Part 1
# 3104                          Batman: Mask of the Phantasm
# Name: title, dtype: object
